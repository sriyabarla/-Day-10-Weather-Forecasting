# %% [markdown]
# <a href="https://colab.research.google.com/github/sriyabarla/-Day-10-Weather-Forecasting/blob/main/HOUSE_PRICE_PREDICTION_day_21.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
data = {
    "area": [1000,1500,1200,1800,2000,1700],
    "bedrooms": [2,3,2,4,4,3],
    "price": [3000000,4500000,3500000,5500000,6000000,5200000]
}

df = pd.DataFrame(data)
df
# Out:
#    area  bedrooms    price
# 0  1000         2  3000000
# 1  1500         3  4500000
# 2  1200         2  3500000
# 3  1800         4  5500000
# 4  2000         4  6000000
# 5  1700         3  5200000

# %%
X = df[['area', 'bedrooms']]   # input
y = df['price']                # output

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
accuracy = model.score(X_test, y_test)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.9856000000000001

# %%
prediction = model.predict([[1500, 3]])
print("Predicted Price:", prediction[0])
# Out:
# Predicted Price: 4450000.000000001
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
